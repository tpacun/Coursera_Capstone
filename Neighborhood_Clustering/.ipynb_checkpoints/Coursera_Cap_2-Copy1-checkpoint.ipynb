# %%
import pandas as pd
import requests
import folium

# %%
#import rev df
df = pd.read_csv('zipcode_data.csv')
df.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
#
#                               Metro       CountyName  1996-01-31  ...  \
# 0       New York-Newark-Jersey City  New York County    233265.0  ...
# 1          Chicago-Naperville-Elgin      Cook County    211748.0  ...
# 2       New York-Newark-Jersey City  New York County    245773.0  ...
# 3  Houston-The Woodlands-Sugar Land    Harris County    200430.0  ...
# 4          Chicago-Naperville-Elgin      Cook County    286382.0  ...
#
#    2019-09-30  2019-10-31  2019-11-30  2019-12-31  2020-01-31  2020-02-29  \
# ...

# %%
#select for boston metro area
metro_area = df[df['Metro'] == 'Boston-Cambridge-Newton']
metro_area.shape
# Out:
# (284, 303)

# %%
metro_map = folium.map(location = boston_center)

# %%
#select for boston neighborhoods, note that metro area 'Boston-Cambridge-Newton' includes unwanted areas ie Plymouth
boston = df[(df['City'] == 'Boston') | (df['City'] == 'Newton') | (df['City'] == 'Cambridge') | (df['City'] == 'Brookline')]
boston.info()
boston
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 105 to 15293
# Columns: 302 entries, RegionID to 2020-05-31
# dtypes: float64(293), int64(2), object(7)
# memory usage: 146.8+ KB
#        RegionID  SizeRank          RegionName    RegionType StateName State  \
# 105      275424       108    South Dorchester  Neighborhood        MA    MA
# 144       54232       148             Roxbury  Neighborhood        MA    MA
# 209      154795       214       Jamaica Plain  Neighborhood        MA    MA
# 217      154399       222         East Boston  Neighborhood        MA    MA
# 230       37575       235            Brighton  Neighborhood        MA    MA
# ...         ...       ...                 ...           ...       ...   ...
# 10005    762189     10460         Griggs Park  Neighborhood        MA    MA
# 10881     15730     11412  Newton Lower Falls  Neighborhood        MA    MA
# 11271    762188     11834      Emerson Garden  Neighborhood        MA    MA
# ...

# %%
#select most recent real estate price and neighborhood names
neighborhoods = boston[['RegionName', 'City', 'State', '2020-05-31']].reset_index(drop= True)
neighborhoods.rename(columns = {'RegionName': 'Neighborhoods', '2020-05-31': 'RE_price'}, inplace = True)
neighborhoods
# Out:
#          Neighborhoods       City State   RE_price
# 0     South Dorchester     Boston    MA   532826.0
# 1              Roxbury     Boston    MA   504773.0
# 2        Jamaica Plain     Boston    MA   655844.0
# 3          East Boston     Boston    MA   529380.0
# 4             Brighton     Boston    MA   552254.0
# ..                 ...        ...   ...        ...
# 57         Griggs Park  Brookline    MA   917390.0
# 58  Newton Lower Falls     Newton    MA   956779.0
# 59      Emerson Garden  Brookline    MA  1293238.0
# 60   Downtown Crossing     Boston    MA  1953245.0
# 61    Leather District     Boston    MA   957771.0
#
# [62 rows x 4 columns]

# %%
#google api data
google_key = 'AIzaSyAJmiz1eaIhZK1J4BH0NsN4640dyHth38Q'

# %%
#function to get coordinates
def get_coord(apikey, address):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&address={}'.format(apikey, address)
        response = requests.get(url).json()
        geo_location = response['results'][0]['geometry']['location']
        lat, lng = geo_location['lat'], geo_location['lng']
        return [lat, lng]
    except:
        return [None, None]

# %%
# get lat, long of boston neighborhoods
neighborhood_coordinates = []
for hood, city, state in zip(neighborhoods['Neighborhoods'], neighborhoods['City'], neighborhoods['State']):
    coordinates = get_coord(google_key, hood + city + state)
    neighborhood_coordinates.append(coordinates)

print(len(neighborhood_coordinates))
# Out:
# 62

# %%
#parse out data to indivual lists
hood_lat, hood_lng = [], []

for i in range(len(neighborhood_coordinates)):
    hood_lat.append(neighborhood_coordinates[i][0])
    hood_lng.append(neighborhood_coordinates[i][1])

print(hood_lat, hood_lng)
# Out:
# [42.30163049999999, 42.3151978, 42.3097365, 42.37021370000001, 42.3463503, 42.2771417, 42.3381437, 42.2565289, 42.2797554, 42.3388111, 42.2832142, 42.30163049999999, 42.3539038, 42.35026480000001, 42.3428653, 42.3782065, None, 42.329617, 42.3933869, 42.3723884, 42.5362044, 42.35830199999999, 42.5278731, 42.3647024, 42.3610389, 42.3497948, 42.3686043, 42.3300503, 42.3467771, 42.3587999, 42.37681569999999, 42.3328668, 42.3328668, 42.3500641, 42.3479782, 42.3028239, 42.3121798, 42.3712968, 36.0679307, None, 42.3182421, 42.3770029, 42.3270215, 42.3356106, 42.35007909999999, None, None, None, 42.3489568, 42.7070354, 42.33093059999999, 44.5202794, 42.3358126, 42.3889681, 41.5737146, 42.3814129, 41.4748563, 42.3386331, 42.3306044, 33.9046735, 42.3554958, 42.3504906] [-71.067605, -71.0913748, -71.1151431, -71.0388601, -71.1626756, -71.0913748, -71.0475773, -71.1240559, -71.1626756, -71.0765188, -71.1270268, -71.067605, -71.1337112, -71.0809757, -71.1002881, -71.0602131, None, -71.1062302, -7
# ...

# %%
#add into df
neighborhoods['Lat'] = hood_lat
neighborhoods['Long'] = hood_lng
neighborhoods.head()
# Out:
#       Neighborhoods State  RE_price        Lat       Long
# 0  South Dorchester    MA  532826.0  42.301630 -71.067605
# 1           Roxbury    MA  504773.0  42.315198 -71.091375
# 2     Jamaica Plain    MA  655844.0  42.309736 -71.115143
# 3       East Boston    MA  529380.0  42.370214 -71.038860
# 4          Brighton    MA  552254.0  42.346350 -71.162676

# %%
df1 = neighborhoods[neighborhoods.isna().any(axis=1)]
df1
# Out:
#         Neighborhoods State   RE_price  Lat  Long
# 16            Kenmore    MA   648440.0  NaN   NaN
# 39  The Port - Area 4    MA   844476.0  NaN   NaN
# 45                MIT    MA   938582.0  NaN   NaN
# 46         Corey Hill    MA  1094715.0  NaN   NaN
# 47           Downtown    MA  1185905.0  NaN   NaN

# %%
#get boston centerpoint
boston_center = get_coord(google_key, 'Boston, MA')
print(boston_center)
# Out:
# [42.3600825, -71.0588801]

# %%
#map boston
map_boston = folium.Map(location = boston_center, zoom_start = 12)
folium.Marker(boston_center, popup = 'Boston Center').add_to(map_boston)
map_boston
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#feature group of neighborhoods
fg_neighborhoods = folium.map.FeatureGroup()

#add neighborhoods to feature group
for lat, lon, neigh in zip(neighborhoods['Lat'], neighborhoods['Long'], neighborhoods['Neighborhoods']):
    fg_neighborhoods.add_child(
        folium.CircleMarker(
            [lat, lon],
            radius = 8,
            color = 'blue',
            fill = True,
            popup = neigh))
    
#add group and display map
map_boston.add_child(fg_neighborhoods)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-31ca7b449fcd> in <module>
#      10             color = 'blue',
#      11             fill = True,
# ---> 12             popup = neigh))
#      13
#      14 #add group and display map
#
# ~\miniconda3\lib\site-packages\folium\vector_layers.py in __init__(self, location, radius, popup, tooltip, **kwargs)
#     303     def __init__(self, location, radius=10, popup=None, tooltip=None, **kwargs):
#     304         super(CircleMarker, self).__init__(location, popup=popup,
# --> 305                                            tooltip=tooltip)
#     306         self._name = 'CircleMarker'
#     307         self.options = path_options(line=False, radius=radius, **kwargs)
#
# ~\miniconda3\lib\site-packages\folium\map.py in __init__(self, location, popup, tooltip, icon, draggable, **kwargs)
# ...

# %%
#after further review,
