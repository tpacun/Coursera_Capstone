# %%
import pandas as pd
import matplotlib.pyplot as plt
import regex
import seaborn as sns
import numpy as np

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
df_starbucks = pd.read_csv('directory.csv')
df_starbucks.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# 1      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.42
# 2      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.39
# 3      NaN          NaN     GMT+04:00 Asia/Dubai      54.38     24.48
# 4      NaN          NaN     GMT+04:00 Asia/Dubai      54.54     24.51

# %%
df_starbucks = df_starbucks[(df_starbucks['Brand'] == 'Starbucks')]
df_starbucks = df_starbucks[df_starbucks['Country'] == 'US'].reset_index(drop=True)
df_starbucks.shape
# Out:
# (13311, 13)

# %%
df_cityre = pd.read_csv('City_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_mon.csv')
df_cityre.head()
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       City        NY    NY
# 1     12447         1  Los Angeles       City        CA    CA
# 2     39051         2      Houston       City        TX    TX
# 3     17426         3      Chicago       City        IL    IL
# 4      6915         4  San Antonio       City        TX    TX
#
#                               Metro          CountyName  1996-01-31  \
# 0       New York-Newark-Jersey City       Queens County    195870.0
# 1    Los Angeles-Long Beach-Anaheim  Los Angeles County    186516.0
# 2  Houston-The Woodlands-Sugar Land       Harris County     94293.0
# 3          Chicago-Naperville-Elgin         Cook County    132510.0
# 4         San Antonio-New Braunfels        Bexar County     94895.0
#
#    1996-02-29  ...  2019-08-31  2019-09-30  2019-10-31  2019-11-30  \
# 0    195305.0  ...    656637.0    655351.0    654130.0    653072.0
# 1    186493.0  ...    722785.0    725378.0    728666.0    731044.0
# 2     94409.0  ...    189782.0    190184.0    190782.0    191229.0
# 3    132361.0  ...    251764.0    251538.0    251343.0    251156.0
# 4     94862.0  ...    185743.0    186661.0    187287.0    188003.0
#
#    2019-12-31  2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31
# 0    652831.0    653085.0    653094.0    652246.0    652106.0    651485.0
# 1    734746.0    738227.0    743785.0    748836.0    752594.0    752510.0
# 2    191748.0    191902.0    192373.0    193260.0    194337.0    195208.0
# 3    251086.0    251261.0    251614.0    252135.0    252342.0    252473.0
# 4    188114.0    188573.0    188630.0    189089.0    189113.0    189246.0
#
# [5 rows x 301 columns]

# %%
df_city50 = df_cityre[0:50]
df_city50.shape
# Out:
# (50, 301)

# %%
top50_rev = df_city50[['RegionName', 'StateName', '2017-01-31']]
top50_rev = top50_rev.rename(columns={"RegionName": "City", "StateName": "State", "2017-01-31": "RE_Value"})
top50_rev.head()
# Out:
#           City State  RE_Value
# 0     New York    NY  584490.0
# 1  Los Angeles    CA  636974.0
# 2      Houston    TX  170083.0
# 3      Chicago    IL  233162.0
# 4  San Antonio    TX  161663.0

# %%
mask = list(df_city50['RegionName'])
top50_star = df_starbucks[df_starbucks['City'].apply(lambda x: True if x in mask else False)]
top50_star_count = top50_star['City'].value_counts().rename_axis('City').reset_index(name = 'NumStarbucks')
top50_star_count.tail()
# Out:
#              City  NumStarbucks
# 45        El Paso            21
# 46      Milwaukee            21
# 47      Cleveland            19
# 48  Oklahoma City            15
# 49        Detroit            10

# %%
rev_star = top50_star_count.merge(top50_rev, left_on = 'City', right_on = 'City')
#.drop('RegionName', inplace = True, axis = 1)
rev_star.head()
# Out:
#         City  NumStarbucks State  RE_Value
# 0   New York           230    NY  584490.0
# 1    Chicago           179    IL  233162.0
# 2  Las Vegas           153    NV  217354.0
# 3    Seattle           151    WA  637004.0
# 4    Houston           151    TX  170083.0

# %%
h = sns.regplot(data = rev_star, x = 'NumStarbucks', y = 'RE_Value')
h.set(xlim = (0, 250), ylim = (0, 1500000))
plt.show()

# %%
x, y = rev_star['NumStarbucks'], rev_star['RE_Value']

plt.clf()
plt.scatter(x, y)
plt.show()

# %%
#!conda install xlrd
#pop_df = pd.read_excel('SUB-IP-EST2019-ANNRES.xlsx')
#pop_df.head()

df_population = pd.read_csv('sub-est2019_all.csv', encoding = 'cp1252')
df_population.head()
# Out:
#    SUMLEV  STATE  COUNTY  PLACE  COUSUB  CONCIT  PRIMGEO_FLAG FUNCSTAT  \
# 0      40      1       0      0       0       0             0        A
# 1     162      1       0    124       0       0             0        A
# 2     162      1       0    460       0       0             0        A
# 3     162      1       0    484       0       0             0        A
# 4     162      1       0    676       0       0             0        A
#
#               NAME   STNAME  ... POPESTIMATE2010  POPESTIMATE2011  \
# 0          Alabama  Alabama  ...         4785437          4799069
# 1   Abbeville city  Alabama  ...            2699             2694
# 2  Adamsville city  Alabama  ...            4500             4493
# 3     Addison town  Alabama  ...             751              750
# 4       Akron town  Alabama  ...             355              347
#
#    POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# 0          4815588          4830081          4841799          4852347
# 1             2643             2628             2608             2600
# 2             4471             4449             4420             4390
# 3              743              742              739              734
# 4              347              343              338              339
#
#    POPESTIMATE2016  POPESTIMATE2017  POPESTIMATE2018  POPESTIMATE2019
# 0          4863525          4874486          4887681          4903185
# 1             2584             2575             2571             2560
# 2             4356             4327             4308             4281
# 3              731              726              723              718
# 4              333              332              331              328
#
# [5 rows x 22 columns]

# %%
df_cities = df_population[(df_population['SUMLEV']== 162)]
df_cities_200 = df_cities.sort_values('POPESTIMATE2017', ascending = False)[0:200]
df_cities_200.shape
# Out:
# (200, 22)

# %%
df_cities_features = df_cities_200[['NAME', 'POPESTIMATE2017', 'STNAME']]
df_cities_features['City'] = df_cities_features['NAME'].str.split(pat = ' town$| city$').str[0]
df_cities_features = df_cities_features.drop(['NAME'], axis = 1)
df_cities_features = df_cities_features.rename(columns = {'POPESTIMATE2017': '2017_Population', 'STNAME':'State'})
df_cities_features.head()
# Out:
# C:\Users\tpacu\miniconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        2017_Population       State         City
# 46586          8437478    New York     New York
# 3092           3975788  California  Los Angeles
# 8173           2711069    Illinois      Chicago
# 71676          2316750       Texas      Houston
# 1512           1633560     Arizona      Phoenix

# %%
df_cities_features['State'].replace(us_state_abbrev, inplace = True)
#mask_state = list(df_city50['StateName'])
 
df_select_cities = df_cities_features[df_cities_features['City'].str.lower().isin([x.lower() for x in mask])]
df_select_cities = df_select_cities.reset_index(drop = True)
df_select_cities.head()
# Out:
#    2017_Population State         City
# 0          8437478    NY     New York
# 1          3975788    CA  Los Angeles
# 2          2711069    IL      Chicago
# 3          2316750    TX      Houston
# 4          1633560    AZ      Phoenix

# %%
final_df = rev_star.merge(df_select_cities, left_on = 'City', right_on = 'City')
final_df.head()
# Out:
#         City  NumStarbucks State_x  RE_Value  2017_Population State_y
# 0   New York           230      NY  584490.0          8437478      NY
# 1    Chicago           179      IL  233162.0          2711069      IL
# 2  Las Vegas           153      NV  217354.0           635262      NV
# 3    Seattle           151      WA  637004.0           728661      WA
# 4    Houston           151      TX  170083.0          2316750      TX

# %%
final_df = final_df[final_df['State_x'] == final_df['State_y']]
final_df['Starbucks_percap'] = final_df['NumStarbucks'] / final_df['2017_Population']
final_df.head()
# Out:
#         City  NumStarbucks State_x  RE_Value  2017_Population State_y  \
# 0   New York           230      NY  584490.0          8437478      NY
# 1    Chicago           179      IL  233162.0          2711069      IL
# 2  Las Vegas           153      NV  217354.0           635262      NV
# 3    Seattle           151      WA  637004.0           728661      WA
# 4    Houston           151      TX  170083.0          2316750      TX
#
#    Starbucks_percap
# 0          0.000027
# 1          0.000066
# 2          0.000241
# 3          0.000207
# 4          0.000065

# %%
g = sns.regplot(x = 'Starbucks_percap', y = 'RE_Value', data = final_df)
plt.show()

# %%
x, y = final_df['Starbucks_percap'], final_df['RE_Value']

plt.clf()
plt.scatter(x, y)

plt.show()

# %%
df_cityre_200 = df_cityre[0:200]
df_cityre_200.head()
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       City        NY    NY
# 1     12447         1  Los Angeles       City        CA    CA
# 2     39051         2      Houston       City        TX    TX
# 3     17426         3      Chicago       City        IL    IL
# 4      6915         4  San Antonio       City        TX    TX
#
#                               Metro          CountyName  1996-01-31  \
# 0       New York-Newark-Jersey City       Queens County    195870.0
# 1    Los Angeles-Long Beach-Anaheim  Los Angeles County    186516.0
# 2  Houston-The Woodlands-Sugar Land       Harris County     94293.0
# 3          Chicago-Naperville-Elgin         Cook County    132510.0
# 4         San Antonio-New Braunfels        Bexar County     94895.0
#
#    1996-02-29  ...  2019-08-31  2019-09-30  2019-10-31  2019-11-30  \
# 0    195305.0  ...    656637.0    655351.0    654130.0    653072.0
# 1    186493.0  ...    722785.0    725378.0    728666.0    731044.0
# 2     94409.0  ...    189782.0    190184.0    190782.0    191229.0
# 3    132361.0  ...    251764.0    251538.0    251343.0    251156.0
# 4     94862.0  ...    185743.0    186661.0    187287.0    188003.0
#
#    2019-12-31  2020-01-31  2020-02-29  2020-03-31  2020-04-30  2020-05-31
# 0    652831.0    653085.0    653094.0    652246.0    652106.0    651485.0
# 1    734746.0    738227.0    743785.0    748836.0    752594.0    752510.0
# 2    191748.0    191902.0    192373.0    193260.0    194337.0    195208.0
# 3    251086.0    251261.0    251614.0    252135.0    252342.0    252473.0
# 4    188114.0    188573.0    188630.0    189089.0    189113.0    189246.0
#
# [5 rows x 301 columns]

# %%
df_cityre_select = df_cityre_200.iloc[:, np.r_[0:7, range(-41,0)]]
df_cityre_select.drop('StateName', axis = 1, inplace = True)
df_cityre_select
# Out:
# C:\Users\tpacu\miniconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      RegionID  SizeRank      RegionName RegionType State  \
# 0        6181         0        New York       City    NY
# 1       12447         1     Los Angeles       City    CA
# 2       39051         2         Houston       City    TX
# 3       17426         3         Chicago       City    IL
# 4        6915         4     San Antonio       City    TX
# ..        ...       ...             ...        ...   ...
# 195     19892       198  Pembroke Pines       City    FL
# 196     38328       199          Edmond       City    OK
# 197     25483       200        Lakeland       City    FL
# 198     47250       201          Pueblo       City    CO
# 199      7221       202     Springfield       City    MA
#
#                                      Metro  2017-01-31  2017-02-28  \
# 0              New York-Newark-Jersey City    584490.0    587315.0
# 1           Los Angeles-Long Beach-Anaheim    636974.0    640135.0
# 2         Houston-The Woodlands-Sugar Land    170083.0    170522.0
# 3                 Chicago-Naperville-Elgin    233162.0    234143.0
# 4                San Antonio-New Braunfels    161663.0    163379.0
# ..                                     ...         ...         ...
# 195  Miami-Fort Lauderdale-West Palm Beach    280375.0    281253.0
# 196                          Oklahoma City    229364.0    229443.0
# 197                  Lakeland-Winter Haven    142468.0    143530.0
# 198                                 Pueblo    145398.0    146352.0
# 199                            Springfield    145554.0    145800.0
#
#      2017-03-31  2017-04-30  ...  2019-08-31  2019-09-30  2019-10-31  \
# 0      590243.0    592324.0  ...    656637.0    655351.0    654130.0
# 1      643839.0    646233.0  ...    722785.0    725378.0    728666.0
# 2      171082.0    172015.0  ...    189782.0    190184.0    190782.0
# 3      236057.0    237438.0  ...    251764.0    251538.0    251343.0
# 4      164425.0    164774.0  ...    185743.0    186661.0    187287.0
# ..          ...         ...  ...         ...         ...         ...
# 195    282129.0    284332.0  ...    314541.0    315432.0    316833.0
# 196    229611.0    230416.0  ...    240428.0    241167.0    241847.0
# 2      0.211374    0.313447    0.233751    0.270668    0.080249    0.244837
# 3     -0.089847   -0.077583   -0.074456   -0.027879    0.069649    0.140294
# 4      0.491801    0.334246    0.380845    0.059007    0.243407    0.030218
# ..          ...         ...         ...         ...         ...         ...
# 195    0.282470    0.442189    0.318394    0.164902    0.332465    0.542385
# 196    0.306427    0.281169    0.270923    0.174126    0.311057    0.241123
# 197    0.235964    0.345038    0.595410    0.639962    0.646441    0.736518
# 198    0.530477    0.563251    0.701864    0.571162    0.650500    0.823186
# 199    0.622865    0.703295    0.651141    0.523999    0.543833    0.877449
#
#      2020-03-31  2020-04-30  2020-05-31
# 0     -0.130012   -0.021469   -0.095321
# 1      0.674514    0.499340   -0.011163
# 2      0.458967    0.554192    0.446191
# 3      0.206635    0.082032    0.051887
# 4      0.242743    0.012691    0.070279
# ..          ...         ...         ...
# 195    0.465174    0.648437    0.677378
# 196    0.481553    0.400094    0.404940
# 197    0.743155    0.600801    0.079278
# 198    0.834077    0.856610    0.830540
# 199    0.406431    0.358675    0.140928
#
# [200 rows x 41 columns]

# %%
annual_chart = changes.iloc[:, ::12]
annual_percent = annual_chart.diff(axis = 1)
#annual_percent = annual_percent / changes
#annual_percent = annual_percent.drop('2017-01-31', axis = 1)
annual_percent = (annual_percent / changes.iloc[:, ::12]) * 100
annual_percent
# Out:
#      2017-01-31  2018-01-31  2019-01-31  2020-01-31
# 0           NaN    6.470376    5.041893   -0.768813
# 1           NaN    7.426392    4.206263    2.701202
# 2           NaN    3.325679    5.619870    2.861877
# 3           NaN    5.164728    2.131640    0.018308
# 4           NaN    5.454705    5.270273    4.279510
# ..          ...         ...         ...         ...
# 195         NaN    5.282236    5.294057    2.151945
# 196         NaN    2.270209    0.338445    3.363358
# 197         NaN    8.770851    8.322669    4.826238
# 198         NaN    9.209664   10.970586    7.206566
# 199         NaN    7.911603    4.225822    6.412576
#
# [200 rows x 4 columns]

# %%
#insert RegionName, State
#changes_merge =

# %%
mask = list(df_cityre['RegionName'])
us_star = df_starbucks[df_starbucks['City'].apply(lambda x: True if x in mask else False)]
us_star_count = us_star.groupby(['State/Province', 'City']).size().reset_index()#.rename_axis('City').reset_index(name = 'NumStarbucks')
print(us_star_count.head())
# Out:
#   State/Province         City   0
# 0             AK    Anchorage  23
# 1             AK  Eagle River   3
# 2             AK    Fairbanks   5
# 3             AK        Homer   1
# 4             AK       Juneau   2

# %%
finaldataframe = pd.merge_ordered(left = us_star_count, right = df_cityre, left_on = 'City', right_on = 'RegionName', how = 'right')
finaldataframe.head(25)
# Out:
#    State/Province      City    0  RegionID  SizeRank   RegionName RegionType  \
# 0             NaN       NaN  NaN     50631     29449   Aaronsburg       City
# 1             NaN       NaN  NaN     23389      2216    Abbeville       City
# 2             NaN       NaN  NaN     37041      4045    Abbeville       City
# 3             NaN       NaN  NaN     10031      7250    Abbeville       City
# 4             NaN       NaN  NaN     50632      9494    Abbeville       City
# 5             NaN       NaN  NaN     30113     13553    Abbeville       City
# 6             NaN       NaN  NaN    398289     23495        Abbot       City
# 7             NaN       NaN  NaN     23390     13272   Abbotsford       City
# 8             NaN       NaN  NaN     37042     20624       Abbott       City
# 9             NaN       NaN  NaN     43810     26932  Abbottstown       City
# 10            NaN       NaN  NaN     37043     26951    Abbyville       City
# 11            NaN       NaN  NaN     30115     28838        Abell       City
# 12            NaN       NaN  NaN     37044     20174  Abercrombie       City
# 13             NC  Aberdeen  1.0     50635      1811     Aberdeen       City
# 14             SD  Aberdeen  2.0     50635      1811     Aberdeen       City
# 15             WA  Aberdeen  2.0     50635      1811     Aberdeen       City
# 16             NC  Aberdeen  1.0     16675      2403     Aberdeen       City
# 17             SD  Aberdeen  2.0     16675      2403     Aberdeen       City
# 18             WA  Aberdeen  2.0     16675      2403     Aberdeen       City
# 19             NC  Aberdeen  1.0     30116      2646     Aberdeen       City
# 20             SD  Aberdeen  2.0     30116      2646     Aberdeen       City
# 21             WA  Aberdeen  2.0     30116      2646     Aberdeen       City
# 22             NC  Aberdeen  1.0      3301      3877     Aberdeen       City
# 23             SD  Aberdeen  2.0      3301      3877     Aberdeen       City
# 24             WA  Aberdeen  2.0      3301      3877     Aberdeen       City
#
#    StateName State                      Metro  ... 2019-08-31  2019-09-30  \
# 0         PA    PA              State College  ...   189327.0    189220.0
# 1         LA    LA                  Lafayette  ...   132088.0    132046.0
# 2         SC    SC                  Greenwood  ...   133378.0    133842.0
# 3         AL    AL                     Dothan  ...    88631.0     89032.0
# 4         GA    GA                        NaN  ...    71650.0     71936.0
# 5         MS    MS                     Oxford  ...   130415.0    130692.0
# 6         ME    ME                        NaN  ...   131585.0    132978.0
# 7         WI    WI                        NaN  ...   119355.0    119441.0
# 8         TX    TX                        NaN  ...   144991.0    145722.0
# 9         PA    PA                 Gettysburg  ...   183619.0    183702.0
# 10        KS    KS                 Hutchinson  ...   108991.0    109021.0
# 11        MD    MD  California-Lexington Park  ...   324522.0    326497.0
# 12        ND    ND                   Wahpeton  ...    91379.0     91981.0
# 13        SD    SD                   Aberdeen  ...   170945.0    171251.0
# 14        SD    SD                   Aberdeen  ...   170945.0    171251.0
# 15        SD    SD                   Aberdeen  ...   170945.0    171251.0
# 16        MD    MD  Baltimore-Columbia-Towson  ...   221156.0    221911.0
# 17        MD    MD  Baltimore-Columbia-Towson  ...   221156.0    221911.0
# 18        MD    MD  Baltimore-Columbia-Towson  ...   221156.0    221911.0
# 19        WA    WA                   Aberdeen  ...   155168.0    156029.0
# 20        WA    WA                   Aberdeen  ...   155168.0    156029.0
# 21        WA    WA                   Aberdeen  ...   155168.0    156029.0
# 22        NC    NC   Pinehurst-Southern Pines  ...   196396.0    197203.0
# 23        NC    NC   Pinehurst-Southern Pines  ...   196396.0    197203.0
# 24        NC    NC   Pinehurst-Southern Pines  ...   196396.0    197203.0
#
#     2019-10-31  2019-11-30  2019-12-31  2020-01-31  2020-02-29  2020-03-31  \
